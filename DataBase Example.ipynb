# %% [markdown]
# # Database construction and example query

# %% [markdown]
# ## Load data into SQLite database

# %% [markdown]
# <p>First please download anb extract the data from https://snap.stanford.edu/data/amazon/Books.txt.gz</p>
# <p>Then change the filePath below to that of the extracted data, in my case it's the root of the notebook</p>
# <p>Lastly, run the code below once. This builds a new file in the project folder which now serve as the database</p>
# <p>Future projects can reuse this database by ... something something about reusing the database file</p>

# %%
import pandas as pd
import numpy as np
from sqlalchemy import create_engine
import datetime as dt

disk_engine = create_engine('sqlite:///ratings.db')

filePath = 'data.csv'

def load_data(chunksize = 20000):
    start = dt.datetime.now()
    j = 0
    index_start = 1
    data_columns = ['UserId', 'ItemId', 'Rating', 'Time']

    for df in pd.read_csv(filePath, names=data_columns, chunksize=chunksize, iterator=True, encoding='utf-8'):
        df.index += index_start
        j+=1
        print('{} seconds: completed {} rows'.format((dt.datetime.now() - start).seconds, j*chunksize))

        df.to_sql('data', disk_engine, if_exists='append')
        index_start = df.index[-1] + 1

load_data()
# Out:
# 0 seconds: completed 20000 rows
# 0 seconds: completed 40000 rows
# 0 seconds: completed 60000 rows
# 0 seconds: completed 80000 rows
# 0 seconds: completed 100000 rows
# 0 seconds: completed 120000 rows
# 1 seconds: completed 140000 rows
# 1 seconds: completed 160000 rows
# 1 seconds: completed 180000 rows
# 1 seconds: completed 200000 rows
# 1 seconds: completed 220000 rows
# 2 seconds: completed 240000 rows
# 2 seconds: completed 260000 rows
# 2 seconds: completed 280000 rows
# 2 seconds: completed 300000 rows
# 2 seconds: completed 320000 rows
# 3 seconds: completed 340000 rows
# 3 seconds: completed 360000 rows
# 3 seconds: completed 380000 rows
# 3 seconds: completed 400000 rows
# 3 seconds: completed 420000 rows
# 4 seconds: completed 440000 rows
# 4 seconds: completed 460000 rows
# 4 seconds: completed 480000 rows
# 4 seconds: completed 500000 rows
# 4 seconds: completed 520000 rows
# 5 seconds: completed 540000 rows
# 5 seconds: completed 560000 rows
# 5 seconds: completed 580000 rows
# 5 seconds: completed 600000 rows
# 5 seconds: completed 620000 rows
# 6 seconds: completed 640000 rows
# 6 seconds: completed 660000 rows
# 6 seconds: completed 680000 rows
# 6 seconds: completed 700000 rows
# 6 seconds: completed 720000 rows
# 7 seconds: completed 740000 rows
# 7 seconds: completed 760000 rows
# 7 seconds: completed 780000 rows
# 7 seconds: completed 800000 rows
# 8 seconds: completed 820000 rows
# 8 seconds: completed 840000 rows
# 8 seconds: completed 860000 rows
# 8 seconds: completed 880000 rows
# 8 seconds: completed 900000 rows
# 9 seconds: completed 920000 rows
# 9 seconds: completed 940000 rows
# 9 seconds: completed 960000 rows
# 9 seconds: completed 980000 rows
# 9 seconds: completed 1000000 rows
# 10 seconds: completed 1020000 rows
# 10 seconds: completed 1040000 rows
# 10 seconds: completed 1060000 rows
# 10 seconds: completed 1080000 rows
# 10 seconds: completed 1100000 rows
# 11 seconds: completed 1120000 rows
# 11 seconds: completed 1140000 rows
# 11 seconds: completed 1160000 rows
# 11 seconds: completed 1180000 rows
# 11 seconds: completed 1200000 rows
# 11 seconds: completed 1220000 rows
# 12 seconds: completed 1240000 rows
# 12 seconds: completed 1260000 rows
# 12 seconds: completed 1280000 rows
# 12 seconds: completed 1300000 rows
# 12 seconds: completed 1320000 rows
# 13 seconds: completed 1340000 rows
# 13 seconds: completed 1360000 rows
# 13 seconds: completed 1380000 rows
# 13 seconds: completed 1400000 rows
# 13 seconds: completed 1420000 rows
# 14 seconds: completed 1440000 rows
# 14 seconds: completed 1460000 rows
# 14 seconds: completed 1480000 rows
# 14 seconds: completed 1500000 rows
# 14 seconds: completed 1520000 rows
# 15 seconds: completed 1540000 rows
# 15 seconds: completed 1560000 rows
# 15 seconds: completed 1580000 rows
# 15 seconds: completed 1600000 rows
# 15 seconds: completed 1620000 rows
# 16 seconds: completed 1640000 rows
# 16 seconds: completed 1660000 rows
# 16 seconds: completed 1680000 rows
# 16 seconds: completed 1700000 rows
# 16 seconds: completed 1720000 rows
# 17 seconds: completed 1740000 rows
# 17 seconds: completed 1760000 rows
# 17 seconds: completed 1780000 rows
# 17 seconds: completed 1800000 rows
# 17 seconds: completed 1820000 rows
# 18 seconds: completed 1840000 rows
# 18 seconds: completed 1860000 rows
# 18 seconds: completed 1880000 rows
# 18 seconds: completed 1900000 rows
# 18 seconds: completed 1920000 rows
# 19 seconds: completed 1940000 rows
# 19 seconds: completed 1960000 rows
# 19 seconds: completed 1980000 rows
# 19 seconds: completed 2000000 rows
# 19 seconds: completed 2020000 rows
# 20 seconds: completed 2040000 rows
# 20 seconds: completed 2060000 rows
# 20 seconds: completed 2080000 rows
# 20 seconds: completed 2100000 rows
# 20 seconds: completed 2120000 rows
# 21 seconds: completed 2140000 rows
# 21 seconds: completed 2160000 rows
# 21 seconds: completed 2180000 rows
# 21 seconds: completed 2200000 rows
# 21 seconds: completed 2220000 rows
# 22 seconds: completed 2240000 rows
# 22 seconds: completed 2260000 rows
# 22 seconds: completed 2280000 rows
# 22 seconds: completed 2300000 rows
# 22 seconds: completed 2320000 rows
# 23 seconds: completed 2340000 rows
# 23 seconds: completed 2360000 rows
# 23 seconds: completed 2380000 rows
# 23 seconds: completed 2400000 rows
# 23 seconds: completed 2420000 rows
# 24 seconds: completed 2440000 rows
# 24 seconds: completed 2460000 rows
# 24 seconds: completed 2480000 rows
# 24 seconds: completed 2500000 rows
# 24 seconds: completed 2520000 rows
# 24 seconds: completed 2540000 rows
# 25 seconds: completed 2560000 rows
# 25 seconds: completed 2580000 rows
# 25 seconds: completed 2600000 rows
# 25 seconds: completed 2620000 rows
# 25 seconds: completed 2640000 rows
# 26 seconds: completed 2660000 rows
# 26 seconds: completed 2680000 rows
# 26 seconds: completed 2700000 rows
# 26 seconds: completed 2720000 rows
# 27 seconds: completed 2740000 rows
# 27 seconds: completed 2760000 rows
# 27 seconds: completed 2780000 rows
# 27 seconds: completed 2800000 rows
# 27 seconds: completed 2820000 rows
# 28 seconds: completed 2840000 rows
# 28 seconds: completed 2860000 rows
# 28 seconds: completed 2880000 rows
# 28 seconds: completed 2900000 rows
# 28 seconds: completed 2920000 rows
# 28 seconds: completed 2940000 rows
# 29 seconds: completed 2960000 rows
# 29 seconds: completed 2980000 rows
# 29 seconds: completed 3000000 rows
# 29 seconds: completed 3020000 rows
# 29 seconds: completed 3040000 rows
# 30 seconds: completed 3060000 rows
# 30 seconds: completed 3080000 rows
# 30 seconds: completed 3100000 rows
# 30 seconds: completed 3120000 rows
# 30 seconds: completed 3140000 rows
# 31 seconds: completed 3160000 rows
# 31 seconds: completed 3180000 rows
# 31 seconds: completed 3200000 rows
# 31 seconds: completed 3220000 rows
# 31 seconds: completed 3240000 rows
# 32 seconds: completed 3260000 rows
# 32 seconds: completed 3280000 rows
# 32 seconds: completed 3300000 rows
# 32 seconds: completed 3320000 rows
# 32 seconds: completed 3340000 rows
# 32 seconds: completed 3360000 rows
# 33 seconds: completed 3380000 rows
# 33 seconds: completed 3400000 rows
# 33 seconds: completed 3420000 rows
# 33 seconds: completed 3440000 rows
# 33 seconds: completed 3460000 rows
# 34 seconds: completed 3480000 rows
# 34 seconds: completed 3500000 rows
# 34 seconds: completed 3520000 rows
# 34 seconds: completed 3540000 rows
# 34 seconds: completed 3560000 rows
# 35 seconds: completed 3580000 rows
# 35 seconds: completed 3600000 rows
# 35 seconds: completed 3620000 rows
# 35 seconds: completed 3640000 rows
# 35 seconds: completed 3660000 rows
# 36 seconds: completed 3680000 rows
# 36 seconds: completed 3700000 rows
# 36 seconds: completed 3720000 rows
# 36 seconds: completed 3740000 rows
# 36 seconds: completed 3760000 rows
# 37 seconds: completed 3780000 rows
# 37 seconds: completed 3800000 rows
# 37 seconds: completed 3820000 rows
# 37 seconds: completed 3840000 rows
# 37 seconds: completed 3860000 rows
# 38 seconds: completed 3880000 rows
# 38 seconds: completed 3900000 rows
# 38 seconds: completed 3920000 rows
# 38 seconds: completed 3940000 rows
# 38 seconds: completed 3960000 rows
# 39 seconds: completed 3980000 rows
# 39 seconds: completed 4000000 rows
# 39 seconds: completed 4020000 rows
# 39 seconds: completed 4040000 rows
# 39 seconds: completed 4060000 rows
# 40 seconds: completed 4080000 rows
# 40 seconds: completed 4100000 rows
# 40 seconds: completed 4120000 rows
# 40 seconds: completed 4140000 rows
# 40 seconds: completed 4160000 rows
# 41 seconds: completed 4180000 rows
# 41 seconds: completed 4200000 rows
# 41 seconds: completed 4220000 rows
# 41 seconds: completed 4240000 rows
# 41 seconds: completed 4260000 rows
# 42 seconds: completed 4280000 rows
# 42 seconds: completed 4300000 rows
# 42 seconds: completed 4320000 rows
# 42 seconds: completed 4340000 rows
# 42 seconds: completed 4360000 rows
# 43 seconds: completed 4380000 rows
# 43 seconds: completed 4400000 rows
# 43 seconds: completed 4420000 rows
# 43 seconds: completed 4440000 rows
# 43 seconds: completed 4460000 rows
# 44 seconds: completed 4480000 rows
# 44 seconds: completed 4500000 rows
# 44 seconds: completed 4520000 rows
# 44 seconds: completed 4540000 rows
# 44 seconds: completed 4560000 rows
# 45 seconds: completed 4580000 rows
# 45 seconds: completed 4600000 rows
# 45 seconds: completed 4620000 rows
# 45 seconds: completed 4640000 rows
# 45 seconds: completed 4660000 rows
# 46 seconds: completed 4680000 rows
# 46 seconds: completed 4700000 rows
# 46 seconds: completed 4720000 rows
# 46 seconds: completed 4740000 rows
# 46 seconds: completed 4760000 rows
# 47 seconds: completed 4780000 rows
# 47 seconds: completed 4800000 rows
# 47 seconds: completed 4820000 rows
# 47 seconds: completed 4840000 rows
# 47 seconds: completed 4860000 rows
# 48 seconds: completed 4880000 rows
# 48 seconds: completed 4900000 rows
# 48 seconds: completed 4920000 rows
# 48 seconds: completed 4940000 rows
# 48 seconds: completed 4960000 rows
# 49 seconds: completed 4980000 rows
# 49 seconds: completed 5000000 rows
# 49 seconds: completed 5020000 rows
# 49 seconds: completed 5040000 rows
# 50 seconds: completed 5060000 rows
# 50 seconds: completed 5080000 rows
# 50 seconds: completed 5100000 rows
# 50 seconds: completed 5120000 rows
# 50 seconds: completed 5140000 rows
# 51 seconds: completed 5160000 rows
# 51 seconds: completed 5180000 rows
# 51 seconds: completed 5200000 rows
# 51 seconds: completed 5220000 rows
# 51 seconds: completed 5240000 rows
# 52 seconds: completed 5260000 rows
# 52 seconds: completed 5280000 rows
# 52 seconds: completed 5300000 rows
# 52 seconds: completed 5320000 rows
# 52 seconds: completed 5340000 rows
# 53 seconds: completed 5360000 rows
# 53 seconds: completed 5380000 rows
# 53 seconds: completed 5400000 rows
# 53 seconds: completed 5420000 rows
# 53 seconds: completed 5440000 rows
# 54 seconds: completed 5460000 rows
# 54 seconds: completed 5480000 rows
# 54 seconds: completed 5500000 rows
# 54 seconds: completed 5520000 rows
# 54 seconds: completed 5540000 rows
# 55 seconds: completed 5560000 rows
# 55 seconds: completed 5580000 rows
# 55 seconds: completed 5600000 rows
# 55 seconds: completed 5620000 rows
# 55 seconds: completed 5640000 rows
# 56 seconds: completed 5660000 rows
# 56 seconds: completed 5680000 rows
# 56 seconds: completed 5700000 rows
# 56 seconds: completed 5720000 rows
# 56 seconds: completed 5740000 rows
# 57 seconds: completed 5760000 rows
# 57 seconds: completed 5780000 rows
# 57 seconds: completed 5800000 rows
# 57 seconds: completed 5820000 rows
# 57 seconds: completed 5840000 rows
# 58 seconds: completed 5860000 rows
# 58 seconds: completed 5880000 rows
# 58 seconds: completed 5900000 rows
# 58 seconds: completed 5920000 rows
# 58 seconds: completed 5940000 rows
# 59 seconds: completed 5960000 rows
# 59 seconds: completed 5980000 rows
# 59 seconds: completed 6000000 rows
# 59 seconds: completed 6020000 rows
# 59 seconds: completed 6040000 rows
# 59 seconds: completed 6060000 rows
# 60 seconds: completed 6080000 rows
# 60 seconds: completed 6100000 rows
# 60 seconds: completed 6120000 rows
# 60 seconds: completed 6140000 rows
# 60 seconds: completed 6160000 rows
# 61 seconds: completed 6180000 rows
# 61 seconds: completed 6200000 rows
# 61 seconds: completed 6220000 rows
# 61 seconds: completed 6240000 rows
# 62 seconds: completed 6260000 rows
# 62 seconds: completed 6280000 rows
# 62 seconds: completed 6300000 rows
# 62 seconds: completed 6320000 rows
# 62 seconds: completed 6340000 rows
# 62 seconds: completed 6360000 rows
# 63 seconds: completed 6380000 rows
# 63 seconds: completed 6400000 rows
# 63 seconds: completed 6420000 rows
# 63 seconds: completed 6440000 rows
# 63 seconds: completed 6460000 rows
# 64 seconds: completed 6480000 rows
# 64 seconds: completed 6500000 rows
# 64 seconds: completed 6520000 rows
# 64 seconds: completed 6540000 rows
# 64 seconds: completed 6560000 rows
# 65 seconds: completed 6580000 rows
# 65 seconds: completed 6600000 rows
# 65 seconds: completed 6620000 rows
# 65 seconds: completed 6640000 rows
# 65 seconds: completed 6660000 rows
# 65 seconds: completed 6680000 rows
# 66 seconds: completed 6700000 rows
# 66 seconds: completed 6720000 rows
# 66 seconds: completed 6740000 rows
# 66 seconds: completed 6760000 rows
# 66 seconds: completed 6780000 rows
# 67 seconds: completed 6800000 rows
# 67 seconds: completed 6820000 rows
# 67 seconds: completed 6840000 rows
# 67 seconds: completed 6860000 rows
# 67 seconds: completed 6880000 rows
# 68 seconds: completed 6900000 rows
# 68 seconds: completed 6920000 rows
# 68 seconds: completed 6940000 rows
# 68 seconds: completed 6960000 rows
# 69 seconds: completed 6980000 rows
# 69 seconds: completed 7000000 rows
# 69 seconds: completed 7020000 rows
# 69 seconds: completed 7040000 rows
# 69 seconds: completed 7060000 rows
# 70 seconds: completed 7080000 rows
# 70 seconds: completed 7100000 rows
# 70 seconds: completed 7120000 rows
# 70 seconds: completed 7140000 rows
# 70 seconds: completed 7160000 rows
# 70 seconds: completed 7180000 rows
# 71 seconds: completed 7200000 rows
# 71 seconds: completed 7220000 rows
# 71 seconds: completed 7240000 rows
# 71 seconds: completed 7260000 rows
# 72 seconds: completed 7280000 rows
# 72 seconds: completed 7300000 rows
# 72 seconds: completed 7320000 rows
# 72 seconds: completed 7340000 rows
# 72 seconds: completed 7360000 rows
# 73 seconds: completed 7380000 rows
# 73 seconds: completed 7400000 rows
# 73 seconds: completed 7420000 rows
# 73 seconds: completed 7440000 rows
# 73 seconds: completed 7460000 rows
# 74 seconds: completed 7480000 rows
# 74 seconds: completed 7500000 rows
# 74 seconds: completed 7520000 rows
# 74 seconds: completed 7540000 rows
# 74 seconds: completed 7560000 rows
# 75 seconds: completed 7580000 rows
# 75 seconds: completed 7600000 rows
# 75 seconds: completed 7620000 rows
# 75 seconds: completed 7640000 rows
# 75 seconds: completed 7660000 rows
# 76 seconds: completed 7680000 rows
# 76 seconds: completed 7700000 rows
# 76 seconds: completed 7720000 rows
# 76 seconds: completed 7740000 rows
# 76 seconds: completed 7760000 rows
# 77 seconds: completed 7780000 rows
# 77 seconds: completed 7800000 rows
# 77 seconds: completed 7820000 rows
# 77 seconds: completed 7840000 rows
# 77 seconds: completed 7860000 rows
# 78 seconds: completed 7880000 rows
# 78 seconds: completed 7900000 rows
# 78 seconds: completed 7920000 rows
# 78 seconds: completed 7940000 rows
# 78 seconds: completed 7960000 rows
# 79 seconds: completed 7980000 rows
# 79 seconds: completed 8000000 rows
# 79 seconds: completed 8020000 rows
# 79 seconds: completed 8040000 rows
# 79 seconds: completed 8060000 rows
# 80 seconds: completed 8080000 rows
# 80 seconds: completed 8100000 rows
# 80 seconds: completed 8120000 rows
# 80 seconds: completed 8140000 rows
# 80 seconds: completed 8160000 rows
# 81 seconds: completed 8180000 rows
# 81 seconds: completed 8200000 rows
# 81 seconds: completed 8220000 rows
# 81 seconds: completed 8240000 rows
# 81 seconds: completed 8260000 rows
# 82 seconds: completed 8280000 rows
# 82 seconds: completed 8300000 rows
# 82 seconds: completed 8320000 rows
# 82 seconds: completed 8340000 rows
# 82 seconds: completed 8360000 rows
# 83 seconds: completed 8380000 rows
# 83 seconds: completed 8400000 rows
# 83 seconds: completed 8420000 rows
# 83 seconds: completed 8440000 rows
# 83 seconds: completed 8460000 rows
# 83 seconds: completed 8480000 rows
# 84 seconds: completed 8500000 rows
# 84 seconds: completed 8520000 rows
# 84 seconds: completed 8540000 rows
# 84 seconds: completed 8560000 rows
# 84 seconds: completed 8580000 rows
# 85 seconds: completed 8600000 rows
# 85 seconds: completed 8620000 rows
# 85 seconds: completed 8640000 rows
# 85 seconds: completed 8660000 rows
# 85 seconds: completed 8680000 rows
# 86 seconds: completed 8700000 rows
# 86 seconds: completed 8720000 rows
# 86 seconds: completed 8740000 rows
# 86 seconds: completed 8760000 rows
# 86 seconds: completed 8780000 rows
# 87 seconds: completed 8800000 rows
# 87 seconds: completed 8820000 rows
# 87 seconds: completed 8840000 rows
# 87 seconds: completed 8860000 rows
# 87 seconds: completed 8880000 rows
# 88 seconds: completed 8900000 rows
# 88 seconds: completed 8920000 rows
# 88 seconds: completed 8940000 rows
# 88 seconds: completed 8960000 rows
# 88 seconds: completed 8980000 rows
# 89 seconds: completed 9000000 rows
# 89 seconds: completed 9020000 rows
# 89 seconds: completed 9040000 rows
# 89 seconds: completed 9060000 rows
# 89 seconds: completed 9080000 rows
# 90 seconds: completed 9100000 rows
# 90 seconds: completed 9120000 rows
# 90 seconds: completed 9140000 rows
# 90 seconds: completed 9160000 rows
# 90 seconds: completed 9180000 rows
# 91 seconds: completed 9200000 rows
# 91 seconds: completed 9220000 rows
# 91 seconds: completed 9240000 rows
# 91 seconds: completed 9260000 rows
# 91 seconds: completed 9280000 rows
# 92 seconds: completed 9300000 rows
# 92 seconds: completed 9320000 rows
# 92 seconds: completed 9340000 rows
# 92 seconds: completed 9360000 rows
# 92 seconds: completed 9380000 rows
# 92 seconds: completed 9400000 rows
# 93 seconds: completed 9420000 rows
# 93 seconds: completed 9440000 rows
# 93 seconds: completed 9460000 rows
# 93 seconds: completed 9480000 rows
# 93 seconds: completed 9500000 rows
# 94 seconds: completed 9520000 rows
# 94 seconds: completed 9540000 rows
# 94 seconds: completed 9560000 rows
# 94 seconds: completed 9580000 rows
# 94 seconds: completed 9600000 rows
# 95 seconds: completed 9620000 rows
# 95 seconds: completed 9640000 rows
# 95 seconds: completed 9660000 rows
# 95 seconds: completed 9680000 rows
# 95 seconds: completed 9700000 rows
# 96 seconds: completed 9720000 rows
# 96 seconds: completed 9740000 rows
# 96 seconds: completed 9760000 rows
# 96 seconds: completed 9780000 rows
# 96 seconds: completed 9800000 rows
# 97 seconds: completed 9820000 rows
# 97 seconds: completed 9840000 rows
# 97 seconds: completed 9860000 rows
# 97 seconds: completed 9880000 rows
# 97 seconds: completed 9900000 rows
# 98 seconds: completed 9920000 rows
# 98 seconds: completed 9940000 rows
# 98 seconds: completed 9960000 rows
# 98 seconds: completed 9980000 rows
# 98 seconds: completed 10000000 rows
# 99 seconds: completed 10020000 rows
# 99 seconds: completed 10040000 rows
# 99 seconds: completed 10060000 rows
# 99 seconds: completed 10080000 rows
# 99 seconds: completed 10100000 rows
# 100 seconds: completed 10120000 rows
# 100 seconds: completed 10140000 rows
# 100 seconds: completed 10160000 rows
# 100 seconds: completed 10180000 rows
# 100 seconds: completed 10200000 rows
# 101 seconds: completed 10220000 rows
# 101 seconds: completed 10240000 rows
# 101 seconds: completed 10260000 rows
# 101 seconds: completed 10280000 rows
# 101 seconds: completed 10300000 rows
# 102 seconds: completed 10320000 rows
# 102 seconds: completed 10340000 rows
# 102 seconds: completed 10360000 rows
# 102 seconds: completed 10380000 rows
# 102 seconds: completed 10400000 rows
# 103 seconds: completed 10420000 rows
# 103 seconds: completed 10440000 rows
# 103 seconds: completed 10460000 rows
# 103 seconds: completed 10480000 rows
# 103 seconds: completed 10500000 rows
# 104 seconds: completed 10520000 rows
# 104 seconds: completed 10540000 rows
# 104 seconds: completed 10560000 rows
# 104 seconds: completed 10580000 rows
# 104 seconds: completed 10600000 rows
# 105 seconds: completed 10620000 rows
# 105 seconds: completed 10640000 rows
# 105 seconds: completed 10660000 rows
# 105 seconds: completed 10680000 rows
# 105 seconds: completed 10700000 rows
# 106 seconds: completed 10720000 rows
# 106 seconds: completed 10740000 rows
# 106 seconds: completed 10760000 rows
# 106 seconds: completed 10780000 rows
# 106 seconds: completed 10800000 rows
# 107 seconds: completed 10820000 rows
# 107 seconds: completed 10840000 rows
# 107 seconds: completed 10860000 rows
# 107 seconds: completed 10880000 rows
# 107 seconds: completed 10900000 rows
# 108 seconds: completed 10920000 rows
# 108 seconds: completed 10940000 rows
# 108 seconds: completed 10960000 rows
# 108 seconds: completed 10980000 rows
# 108 seconds: completed 11000000 rows
# 109 seconds: completed 11020000 rows
# 109 seconds: completed 11040000 rows
# 109 seconds: completed 11060000 rows
# 109 seconds: completed 11080000 rows
# 109 seconds: completed 11100000 rows
# 110 seconds: completed 11120000 rows
# 110 seconds: completed 11140000 rows
# 110 seconds: completed 11160000 rows
# 110 seconds: completed 11180000 rows
# 110 seconds: completed 11200000 rows
# 111 seconds: completed 11220000 rows
# 111 seconds: completed 11240000 rows
# 111 seconds: completed 11260000 rows
# 111 seconds: completed 11280000 rows
# 111 seconds: completed 11300000 rows
# 112 seconds: completed 11320000 rows
# 112 seconds: completed 11340000 rows
# 112 seconds: completed 11360000 rows
# 112 seconds: completed 11380000 rows
# 112 seconds: completed 11400000 rows
# 113 seconds: completed 11420000 rows
# 113 seconds: completed 11440000 rows
# 113 seconds: completed 11460000 rows
# 113 seconds: completed 11480000 rows
# 113 seconds: completed 11500000 rows
# 114 seconds: completed 11520000 rows
# 114 seconds: completed 11540000 rows
# 114 seconds: completed 11560000 rows
# 114 seconds: completed 11580000 rows
# 114 seconds: completed 11600000 rows
# 115 seconds: completed 11620000 rows
# 115 seconds: completed 11640000 rows
# 115 seconds: completed 11660000 rows
# 115 seconds: completed 11680000 rows
# 115 seconds: completed 11700000 rows
# 116 seconds: completed 11720000 rows
# 116 seconds: completed 11740000 rows
# 116 seconds: completed 11760000 rows
# 116 seconds: completed 11780000 rows
# 116 seconds: completed 11800000 rows
# 117 seconds: completed 11820000 rows
# 117 seconds: completed 11840000 rows
# 117 seconds: completed 11860000 rows
# 117 seconds: completed 11880000 rows
# 117 seconds: completed 11900000 rows
# 118 seconds: completed 11920000 rows
# 118 seconds: completed 11940000 rows
# 118 seconds: completed 11960000 rows
# 118 seconds: completed 11980000 rows
# 118 seconds: completed 12000000 rows
# 119 seconds: completed 12020000 rows
# 119 seconds: completed 12040000 rows
# 119 seconds: completed 12060000 rows
# 119 seconds: completed 12080000 rows
# 119 seconds: completed 12100000 rows
# 120 seconds: completed 12120000 rows
# 120 seconds: completed 12140000 rows
# 120 seconds: completed 12160000 rows
# 120 seconds: completed 12180000 rows
# 120 seconds: completed 12200000 rows
# 121 seconds: completed 12220000 rows
# 121 seconds: completed 12240000 rows
# 121 seconds: completed 12260000 rows
# 121 seconds: completed 12280000 rows
# 121 seconds: completed 12300000 rows
# 122 seconds: completed 12320000 rows
# 122 seconds: completed 12340000 rows
# 122 seconds: completed 12360000 rows
# 122 seconds: completed 12380000 rows
# 122 seconds: completed 12400000 rows
# 123 seconds: completed 12420000 rows
# 123 seconds: completed 12440000 rows
# 123 seconds: completed 12460000 rows
# 123 seconds: completed 12480000 rows
# 123 seconds: completed 12500000 rows
# 124 seconds: completed 12520000 rows
# 124 seconds: completed 12540000 rows
# 124 seconds: completed 12560000 rows
# 124 seconds: completed 12580000 rows
# 125 seconds: completed 12600000 rows
# 125 seconds: completed 12620000 rows
# 125 seconds: completed 12640000 rows
# 125 seconds: completed 12660000 rows
# 125 seconds: completed 12680000 rows
# 125 seconds: completed 12700000 rows
# 126 seconds: completed 12720000 rows
# 126 seconds: completed 12740000 rows
# 126 seconds: completed 12760000 rows
# 126 seconds: completed 12780000 rows
# 127 seconds: completed 12800000 rows
# 127 seconds: completed 12820000 rows
# 127 seconds: completed 12840000 rows
# 127 seconds: completed 12860000 rows
# 127 seconds: completed 12880000 rows
# 128 seconds: completed 12900000 rows
# 128 seconds: completed 12920000 rows
# 128 seconds: completed 12940000 rows
# 128 seconds: completed 12960000 rows
# 129 seconds: completed 12980000 rows
# 129 seconds: completed 13000000 rows
# 129 seconds: completed 13020000 rows
# 129 seconds: completed 13040000 rows
# 130 seconds: completed 13060000 rows
# 130 seconds: completed 13080000 rows
# 130 seconds: completed 13100000 rows
# 130 seconds: completed 13120000 rows
# 130 seconds: completed 13140000 rows
# 131 seconds: completed 13160000 rows
# 131 seconds: completed 13180000 rows
# 131 seconds: completed 13200000 rows
# 131 seconds: completed 13220000 rows
# 131 seconds: completed 13240000 rows
# 132 seconds: completed 13260000 rows
# 132 seconds: completed 13280000 rows
# 132 seconds: completed 13300000 rows
# 132 seconds: completed 13320000 rows
# 133 seconds: completed 13340000 rows
# 133 seconds: completed 13360000 rows
# 133 seconds: completed 13380000 rows
# 133 seconds: completed 13400000 rows
# 133 seconds: completed 13420000 rows
# 134 seconds: completed 13440000 rows
# 134 seconds: completed 13460000 rows
# 134 seconds: completed 13480000 rows
# 134 seconds: completed 13500000 rows
# 134 seconds: completed 13520000 rows
# 135 seconds: completed 13540000 rows
# 135 seconds: completed 13560000 rows
# 135 seconds: completed 13580000 rows
# 135 seconds: completed 13600000 rows
# 136 seconds: completed 13620000 rows
# 136 seconds: completed 13640000 rows
# 136 seconds: completed 13660000 rows
# 136 seconds: completed 13680000 rows
# 137 seconds: completed 13700000 rows
# 137 seconds: completed 13720000 rows
# 137 seconds: completed 13740000 rows
# 137 seconds: completed 13760000 rows
# 137 seconds: completed 13780000 rows
# 138 seconds: completed 13800000 rows
# 138 seconds: completed 13820000 rows
# 138 seconds: completed 13840000 rows
# 138 seconds: completed 13860000 rows
# 139 seconds: completed 13880000 rows
# 139 seconds: completed 13900000 rows
# 139 seconds: completed 13920000 rows
# 139 seconds: completed 13940000 rows
# 140 seconds: completed 13960000 rows
# 140 seconds: completed 13980000 rows
# 140 seconds: completed 14000000 rows
# 140 seconds: completed 14020000 rows
# 140 seconds: completed 14040000 rows
# 141 seconds: completed 14060000 rows
# 141 seconds: completed 14080000 rows
# 141 seconds: completed 14100000 rows
# 141 seconds: completed 14120000 rows
# 142 seconds: completed 14140000 rows
# 142 seconds: completed 14160000 rows
# 142 seconds: completed 14180000 rows
# 142 seconds: completed 14200000 rows
# 142 seconds: completed 14220000 rows
# 143 seconds: completed 14240000 rows
# 143 seconds: completed 14260000 rows
# 143 seconds: completed 14280000 rows
# 143 seconds: completed 14300000 rows
# 144 seconds: completed 14320000 rows
# 144 seconds: completed 14340000 rows
# 144 seconds: completed 14360000 rows
# 144 seconds: completed 14380000 rows
# 144 seconds: completed 14400000 rows
# 145 seconds: completed 14420000 rows
# 145 seconds: completed 14440000 rows
# 145 seconds: completed 14460000 rows
# 145 seconds: completed 14480000 rows
# 145 seconds: completed 14500000 rows
# 146 seconds: completed 14520000 rows
# 146 seconds: completed 14540000 rows
# 146 seconds: completed 14560000 rows
# 146 seconds: completed 14580000 rows
# 147 seconds: completed 14600000 rows
# 147 seconds: completed 14620000 rows
# 147 seconds: completed 14640000 rows
# 147 seconds: completed 14660000 rows
# 148 seconds: completed 14680000 rows
# 148 seconds: completed 14700000 rows
# 148 seconds: completed 14720000 rows
# 148 seconds: completed 14740000 rows
# 148 seconds: completed 14760000 rows
# 149 seconds: completed 14780000 rows
# 149 seconds: completed 14800000 rows
# 149 seconds: completed 14820000 rows
# 149 seconds: completed 14840000 rows
# 149 seconds: completed 14860000 rows
# 150 seconds: completed 14880000 rows
# 150 seconds: completed 14900000 rows
# 150 seconds: completed 14920000 rows
# 150 seconds: completed 14940000 rows
# 151 seconds: completed 14960000 rows
# 151 seconds: completed 14980000 rows
# 151 seconds: completed 15000000 rows
# 151 seconds: completed 15020000 rows
# 151 seconds: completed 15040000 rows
# 152 seconds: completed 15060000 rows
# 152 seconds: completed 15080000 rows
# 152 seconds: completed 15100000 rows
# 152 seconds: completed 15120000 rows
# 153 seconds: completed 15140000 rows
# 153 seconds: completed 15160000 rows
# 153 seconds: completed 15180000 rows
# 153 seconds: completed 15200000 rows
# 154 seconds: completed 15220000 rows
# 154 seconds: completed 15240000 rows
# 154 seconds: completed 15260000 rows
# 154 seconds: completed 15280000 rows
# 154 seconds: completed 15300000 rows
# 155 seconds: completed 15320000 rows
# 155 seconds: completed 15340000 rows
# 155 seconds: completed 15360000 rows
# 155 seconds: completed 15380000 rows
# 155 seconds: completed 15400000 rows
# 156 seconds: completed 15420000 rows
# 156 seconds: completed 15440000 rows
# 156 seconds: completed 15460000 rows
# 156 seconds: completed 15480000 rows
# 157 seconds: completed 15500000 rows
# 157 seconds: completed 15520000 rows
# 157 seconds: completed 15540000 rows
# 157 seconds: completed 15560000 rows
# 157 seconds: completed 15580000 rows
# 158 seconds: completed 15600000 rows
# 158 seconds: completed 15620000 rows
# 158 seconds: completed 15640000 rows
# 158 seconds: completed 15660000 rows
# 158 seconds: completed 15680000 rows
# 159 seconds: completed 15700000 rows
# 159 seconds: completed 15720000 rows
# 159 seconds: completed 15740000 rows
# 159 seconds: completed 15760000 rows
# 160 seconds: completed 15780000 rows
# 160 seconds: completed 15800000 rows
# 160 seconds: completed 15820000 rows
# 160 seconds: completed 15840000 rows
# 160 seconds: completed 15860000 rows
# 161 seconds: completed 15880000 rows
# 161 seconds: completed 15900000 rows
# 161 seconds: completed 15920000 rows
# 161 seconds: completed 15940000 rows
# 162 seconds: completed 15960000 rows
# 162 seconds: completed 15980000 rows
# 162 seconds: completed 16000000 rows
# 162 seconds: completed 16020000 rows
# 162 seconds: completed 16040000 rows
# 163 seconds: completed 16060000 rows
# 163 seconds: completed 16080000 rows
# 163 seconds: completed 16100000 rows
# 163 seconds: completed 16120000 rows
# 163 seconds: completed 16140000 rows
# 164 seconds: completed 16160000 rows
# 164 seconds: completed 16180000 rows
# 164 seconds: completed 16200000 rows
# 164 seconds: completed 16220000 rows
# 165 seconds: completed 16240000 rows
# 165 seconds: completed 16260000 rows
# 165 seconds: completed 16280000 rows
# 165 seconds: completed 16300000 rows
# 165 seconds: completed 16320000 rows
# 166 seconds: completed 16340000 rows
# 166 seconds: completed 16360000 rows
# 166 seconds: completed 16380000 rows
# 166 seconds: completed 16400000 rows
# 167 seconds: completed 16420000 rows
# 167 seconds: completed 16440000 rows
# 167 seconds: completed 16460000 rows
# 167 seconds: completed 16480000 rows
# 167 seconds: completed 16500000 rows
# 168 seconds: completed 16520000 rows
# 168 seconds: completed 16540000 rows
# 168 seconds: completed 16560000 rows
# 168 seconds: completed 16580000 rows
# 169 seconds: completed 16600000 rows
# 169 seconds: completed 16620000 rows
# 169 seconds: completed 16640000 rows
# 169 seconds: completed 16660000 rows
# 169 seconds: completed 16680000 rows
# 170 seconds: completed 16700000 rows
# 170 seconds: completed 16720000 rows
# 170 seconds: completed 16740000 rows
# 170 seconds: completed 16760000 rows
# 171 seconds: completed 16780000 rows
# 171 seconds: completed 16800000 rows
# 171 seconds: completed 16820000 rows
# 171 seconds: completed 16840000 rows
# 171 seconds: completed 16860000 rows
# 172 seconds: completed 16880000 rows
# 172 seconds: completed 16900000 rows
# 172 seconds: completed 16920000 rows
# 172 seconds: completed 16940000 rows
# 172 seconds: completed 16960000 rows
# 173 seconds: completed 16980000 rows
# 173 seconds: completed 17000000 rows
# 173 seconds: completed 17020000 rows
# 173 seconds: completed 17040000 rows
# 174 seconds: completed 17060000 rows
# 174 seconds: completed 17080000 rows
# 174 seconds: completed 17100000 rows
# 174 seconds: completed 17120000 rows
# 174 seconds: completed 17140000 rows
# 175 seconds: completed 17160000 rows
# 175 seconds: completed 17180000 rows
# 175 seconds: completed 17200000 rows
# 175 seconds: completed 17220000 rows
# 176 seconds: completed 17240000 rows
# 176 seconds: completed 17260000 rows
# 176 seconds: completed 17280000 rows
# 176 seconds: completed 17300000 rows
# 176 seconds: completed 17320000 rows
# 177 seconds: completed 17340000 rows
# 177 seconds: completed 17360000 rows
# 177 seconds: completed 17380000 rows
# 177 seconds: completed 17400000 rows
# 177 seconds: completed 17420000 rows
# 178 seconds: completed 17440000 rows
# 178 seconds: completed 17460000 rows
# 178 seconds: completed 17480000 rows
# 178 seconds: completed 17500000 rows
# 178 seconds: completed 17520000 rows
# 179 seconds: completed 17540000 rows
# 179 seconds: completed 17560000 rows
# 179 seconds: completed 17580000 rows
# 179 seconds: completed 17600000 rows
# 180 seconds: completed 17620000 rows
# 180 seconds: completed 17640000 rows
# 180 seconds: completed 17660000 rows
# 180 seconds: completed 17680000 rows
# 180 seconds: completed 17700000 rows
# 181 seconds: completed 17720000 rows
# 181 seconds: completed 17740000 rows
# 181 seconds: completed 17760000 rows
# 181 seconds: completed 17780000 rows
# 182 seconds: completed 17800000 rows
# 182 seconds: completed 17820000 rows
# 182 seconds: completed 17840000 rows
# 182 seconds: completed 17860000 rows
# 182 seconds: completed 17880000 rows
# 183 seconds: completed 17900000 rows
# 183 seconds: completed 17920000 rows
# 183 seconds: completed 17940000 rows
# 183 seconds: completed 17960000 rows
# 183 seconds: completed 17980000 rows
# 184 seconds: completed 18000000 rows
# 184 seconds: completed 18020000 rows
# 184 seconds: completed 18040000 rows
# 184 seconds: completed 18060000 rows
# 185 seconds: completed 18080000 rows
# 185 seconds: completed 18100000 rows
# 185 seconds: completed 18120000 rows
# 185 seconds: completed 18140000 rows
# 185 seconds: completed 18160000 rows
# 186 seconds: completed 18180000 rows
# 186 seconds: completed 18200000 rows
# 186 seconds: completed 18220000 rows
# 186 seconds: completed 18240000 rows
# 186 seconds: completed 18260000 rows
# 187 seconds: completed 18280000 rows
# 187 seconds: completed 18300000 rows
# 187 seconds: completed 18320000 rows
# 187 seconds: completed 18340000 rows
# 188 seconds: completed 18360000 rows
# 188 seconds: completed 18380000 rows
# 188 seconds: completed 18400000 rows
# 188 seconds: completed 18420000 rows
# 188 seconds: completed 18440000 rows
# 189 seconds: completed 18460000 rows
# 189 seconds: completed 18480000 rows
# 189 seconds: completed 18500000 rows
# 189 seconds: completed 18520000 rows
# 190 seconds: completed 18540000 rows
# 190 seconds: completed 18560000 rows
# 190 seconds: completed 18580000 rows
# 190 seconds: completed 18600000 rows
# 190 seconds: completed 18620000 rows
# 191 seconds: completed 18640000 rows
# 191 seconds: completed 18660000 rows
# 191 seconds: completed 18680000 rows
# 191 seconds: completed 18700000 rows
# 191 seconds: completed 18720000 rows
# 192 seconds: completed 18740000 rows
# 192 seconds: completed 18760000 rows
# 192 seconds: completed 18780000 rows
# 192 seconds: completed 18800000 rows
# 193 seconds: completed 18820000 rows
# 193 seconds: completed 18840000 rows
# 193 seconds: completed 18860000 rows
# 193 seconds: completed 18880000 rows
# 193 seconds: completed 18900000 rows
# 194 seconds: completed 18920000 rows
# 194 seconds: completed 18940000 rows
# 194 seconds: completed 18960000 rows
# 194 seconds: completed 18980000 rows
# 194 seconds: completed 19000000 rows
# 195 seconds: completed 19020000 rows
# 195 seconds: completed 19040000 rows
# 195 seconds: completed 19060000 rows
# 195 seconds: completed 19080000 rows
# 196 seconds: completed 19100000 rows
# 196 seconds: completed 19120000 rows
# 196 seconds: completed 19140000 rows
# 196 seconds: completed 19160000 rows
# 197 seconds: completed 19180000 rows
# 197 seconds: completed 19200000 rows
# 197 seconds: completed 19220000 rows
# 197 seconds: completed 19240000 rows
# 197 seconds: completed 19260000 rows
# 198 seconds: completed 19280000 rows
# 198 seconds: completed 19300000 rows
# 198 seconds: completed 19320000 rows
# 198 seconds: completed 19340000 rows
# 198 seconds: completed 19360000 rows
# 199 seconds: completed 19380000 rows
# 199 seconds: completed 19400000 rows
# 199 seconds: completed 19420000 rows
# 199 seconds: completed 19440000 rows
# 200 seconds: completed 19460000 rows
# 200 seconds: completed 19480000 rows
# 200 seconds: completed 19500000 rows
# 200 seconds: completed 19520000 rows
# 200 seconds: completed 19540000 rows
# 201 seconds: completed 19560000 rows
# 201 seconds: completed 19580000 rows
# 201 seconds: completed 19600000 rows
# 201 seconds: completed 19620000 rows
# 202 seconds: completed 19640000 rows
# 202 seconds: completed 19660000 rows
# 202 seconds: completed 19680000 rows
# 202 seconds: completed 19700000 rows
# 202 seconds: completed 19720000 rows
# 203 seconds: completed 19740000 rows
# 203 seconds: completed 19760000 rows
# 203 seconds: completed 19780000 rows
# 203 seconds: completed 19800000 rows
# 203 seconds: completed 19820000 rows
# 204 seconds: completed 19840000 rows
# 204 seconds: completed 19860000 rows
# 204 seconds: completed 19880000 rows
# 204 seconds: completed 19900000 rows
# 205 seconds: completed 19920000 rows
# 205 seconds: completed 19940000 rows
# 205 seconds: completed 19960000 rows
# 205 seconds: completed 19980000 rows
# 205 seconds: completed 20000000 rows
# 206 seconds: completed 20020000 rows
# 206 seconds: completed 20040000 rows
# 206 seconds: completed 20060000 rows
# 206 seconds: completed 20080000 rows
# 207 seconds: completed 20100000 rows
# 207 seconds: completed 20120000 rows
# 207 seconds: completed 20140000 rows
# 207 seconds: completed 20160000 rows
# 207 seconds: completed 20180000 rows
# 207 seconds: completed 20200000 rows
# 208 seconds: completed 20220000 rows
# 208 seconds: completed 20240000 rows
# 208 seconds: completed 20260000 rows
# 208 seconds: completed 20280000 rows
# 209 seconds: completed 20300000 rows
# 209 seconds: completed 20320000 rows
# 209 seconds: completed 20340000 rows
# 209 seconds: completed 20360000 rows
# 209 seconds: completed 20380000 rows
# 210 seconds: completed 20400000 rows
# 210 seconds: completed 20420000 rows
# 210 seconds: completed 20440000 rows
# 210 seconds: completed 20460000 rows
# 210 seconds: completed 20480000 rows
# 211 seconds: completed 20500000 rows
# 211 seconds: completed 20520000 rows
# 211 seconds: completed 20540000 rows
# 211 seconds: completed 20560000 rows
# 211 seconds: completed 20580000 rows
# 212 seconds: completed 20600000 rows
# 212 seconds: completed 20620000 rows
# 212 seconds: completed 20640000 rows
# 212 seconds: completed 20660000 rows
# 212 seconds: completed 20680000 rows
# 213 seconds: completed 20700000 rows
# 213 seconds: completed 20720000 rows
# 213 seconds: completed 20740000 rows
# 213 seconds: completed 20760000 rows
# 214 seconds: completed 20780000 rows
# 214 seconds: completed 20800000 rows
# 214 seconds: completed 20820000 rows
# 214 seconds: completed 20840000 rows
# 214 seconds: completed 20860000 rows
# 215 seconds: completed 20880000 rows
# 215 seconds: completed 20900000 rows
# 215 seconds: completed 20920000 rows
# 215 seconds: completed 20940000 rows
# 216 seconds: completed 20960000 rows
# 216 seconds: completed 20980000 rows
# 216 seconds: completed 21000000 rows
# 216 seconds: completed 21020000 rows
# 216 seconds: completed 21040000 rows
# 217 seconds: completed 21060000 rows
# 217 seconds: completed 21080000 rows
# 217 seconds: completed 21100000 rows
# 217 seconds: completed 21120000 rows
# 218 seconds: completed 21140000 rows
# 218 seconds: completed 21160000 rows
# 218 seconds: completed 21180000 rows
# 218 seconds: completed 21200000 rows
# 218 seconds: completed 21220000 rows
# 219 seconds: completed 21240000 rows
# 219 seconds: completed 21260000 rows
# 219 seconds: completed 21280000 rows
# 219 seconds: completed 21300000 rows
# 220 seconds: completed 21320000 rows
# 220 seconds: completed 21340000 rows
# 220 seconds: completed 21360000 rows
# 220 seconds: completed 21380000 rows
# 220 seconds: completed 21400000 rows
# 221 seconds: completed 21420000 rows
# 221 seconds: completed 21440000 rows
# 221 seconds: completed 21460000 rows
# 221 seconds: completed 21480000 rows
# 221 seconds: completed 21500000 rows
# 222 seconds: completed 21520000 rows
# 222 seconds: completed 21540000 rows
# 222 seconds: completed 21560000 rows
# 222 seconds: completed 21580000 rows
# 223 seconds: completed 21600000 rows
# 223 seconds: completed 21620000 rows
# 223 seconds: completed 21640000 rows
# 223 seconds: completed 21660000 rows
# 223 seconds: completed 21680000 rows
# 224 seconds: completed 21700000 rows
# 224 seconds: completed 21720000 rows
# 224 seconds: completed 21740000 rows
# 224 seconds: completed 21760000 rows
# 225 seconds: completed 21780000 rows
# 225 seconds: completed 21800000 rows
# 225 seconds: completed 21820000 rows
# 225 seconds: completed 21840000 rows
# 225 seconds: completed 21860000 rows
# 226 seconds: completed 21880000 rows
# 226 seconds: completed 21900000 rows
# 226 seconds: completed 21920000 rows
# 226 seconds: completed 21940000 rows
# 227 seconds: completed 21960000 rows
# 227 seconds: completed 21980000 rows
# 227 seconds: completed 22000000 rows
# 227 seconds: completed 22020000 rows
# 227 seconds: completed 22040000 rows
# 228 seconds: completed 22060000 rows
# 228 seconds: completed 22080000 rows
# 228 seconds: completed 22100000 rows
# 228 seconds: completed 22120000 rows
# 229 seconds: completed 22140000 rows
# 229 seconds: completed 22160000 rows
# 229 seconds: completed 22180000 rows
# 229 seconds: completed 22200000 rows
# 229 seconds: completed 22220000 rows
# 230 seconds: completed 22240000 rows
# 230 seconds: completed 22260000 rows
# 230 seconds: completed 22280000 rows
# 230 seconds: completed 22300000 rows
# 231 seconds: completed 22320000 rows
# 231 seconds: completed 22340000 rows
# 231 seconds: completed 22360000 rows
# 231 seconds: completed 22380000 rows
# 231 seconds: completed 22400000 rows
# 232 seconds: completed 22420000 rows
# 232 seconds: completed 22440000 rows
# 232 seconds: completed 22460000 rows
# 232 seconds: completed 22480000 rows
# 233 seconds: completed 22500000 rows
# 233 seconds: completed 22520000 rows

# %% [markdown]
# ## Query data from database

# %%
ratings_df = pd.read_sql_query('SELECT `UserId`, `ItemId`, `Rating` FROM `data` WHERE `UserId` IN (SELECT `UserId` '
                       'FROM `data`'
                       'GROUP BY `UserId`'
                       'HAVING COUNT(`Rating`) > 20)', disk_engine)

R_df = ratings_df.pivot(index = 'UserId', columns ='ItemId', values = 'Rating').fillna(0)
R_df.head()
# Out:
# ---------------------------------------------------------------------------
# MemoryError                               Traceback (most recent call last)
# <ipython-input-4-d3e9b5876ad3> in <module>()
#       4                        'HAVING COUNT(`Rating`) > 20)', disk_engine)
#       5
# ----> 6 R_df = ratings_df.pivot(index = 'UserId', columns ='ItemId', values = 'Rating').fillna(0)
#       7 R_df.head()
#
# /home/bs/anaconda3/lib/python3.6/site-packages/pandas/core/frame.py in pivot(self, index, columns, values)
#    3933         """
#    3934         from pandas.core.reshape import pivot
# -> 3935         return pivot(self, index=index, columns=columns, values=values)
#    3936
#    3937     def stack(self, level=-1, dropna=True):
#
# /home/bs/anaconda3/lib/python3.6/site-packages/pandas/core/reshape.py in pivot(self, index, columns, values)
#     336         indexed = Series(self[values].values,
#     337                          index=MultiIndex.from_arrays([index, self[columns]]))
# --> 338         return indexed.unstack(columns)
#     339
#     340
#
# /home/bs/anaconda3/lib/python3.6/site-packages/pandas/core/series.py in unstack(self, level, fill_value)
#    2088         """
#    2089         from pandas.core.reshape import unstack
# -> 2090         return unstack(self, level, fill_value)
#    2091
#    2092     # ----------------------------------------------------------------------
#
# /home/bs/anaconda3/lib/python3.6/site-packages/pandas/core/reshape.py in unstack(obj, level, fill_value)
#     411     else:
#     412         unstacker = _Unstacker(obj.values, obj.index, level=level,
# --> 413                                fill_value=fill_value)
#     414         return unstacker.get_result()
#     415
#
# /home/bs/anaconda3/lib/python3.6/site-packages/pandas/core/reshape.py in __init__(self, values, index, level, value_columns, fill_value)
#     101
#     102         self._make_sorted_values_labels()
# --> 103         self._make_selectors()
#     104
#     105     def _make_sorted_values_labels(self):
#
# /home/bs/anaconda3/lib/python3.6/site-packages/pandas/core/reshape.py in _make_selectors(self)
#     135
#     136         selector = self.sorted_labels[-1] + stride * comp_index + self.lift
# --> 137         mask = np.zeros(np.prod(self.full_shape), dtype=bool)
#     138         mask.put(selector, True)
#     139
#
# MemoryError:
